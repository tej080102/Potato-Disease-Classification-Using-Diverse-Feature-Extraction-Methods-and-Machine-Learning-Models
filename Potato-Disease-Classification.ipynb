# %% [markdown]
# ## Library Import

# %%
import os
import pandas as pd
import numpy as np
from PIL import Image, ImageOps
import plotly.express as px
import matplotlib.pyplot as plt
import seaborn as sns
import cv2
from tqdm import tqdm
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
import time

import tensorflow as tf


import keras
from keras import layers
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from sklearn.metrics import classification_report
from tensorflow.keras.callbacks import EarlyStopping
from keras.preprocessing.image import ImageDataGenerator


from sklearn.naive_bayes import MultinomialNB


import xgboost as xgb
from sklearn import svm
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# %% [markdown]
# ## Data preprocessing

# %%
# label tagging to the images

levels = ['Potato___Early_blight', 'Potato___healthy', 'Potato___Late_blight']
path = r"C:\Users\tejus\Desktop\shannu potato\PlantVillage"
data_dir = os.path.join(path)

data = []
for id, level in enumerate(levels):
    for file in os.listdir(os.path.join(data_dir, level)):
        data.append(['{}/{}'.format(level, file), level])

data = pd.DataFrame(data, columns = ['image_file', 'result'])

data['path'] = path + '/' + data['image_file']

data.head()
# Out:
#                                           image_file                 result  \
# 0  Potato___Early_blight/001187a0-57ab-4329-baff-...  Potato___Early_blight
# 1  Potato___Early_blight/002a55fb-7a3d-4a3a-aca8-...  Potato___Early_blight
# 2  Potato___Early_blight/009c8c31-f22d-4ffd-8f16-...  Potato___Early_blight
# 3  Potato___Early_blight/00d8f10f-5038-4e0f-bb58-...  Potato___Early_blight
# 4  Potato___Early_blight/0182e991-97f0-4805-a1f7-...  Potato___Early_blight
#
#                                                 path
# 0  C:\Users\tejus\Desktop\shannu potato\PlantVill...
# 1  C:\Users\tejus\Desktop\shannu potato\PlantVill...
# 2  C:\Users\tejus\Desktop\shannu potato\PlantVill...
# 3  C:\Users\tejus\Desktop\shannu potato\PlantVill...
# 4  C:\Users\tejus\Desktop\shannu potato\PlantVill...

# %%
print("Numbers of images: {}".format(data.shape[0]))
# Out:
# Numbers of images: 2780

# %%
print(data['result'].unique())
# Out:
# ['Potato___Early_blight' 'Potato___healthy' 'Potato___Late_blight']

# %%
print(data[data['result'].isnull()])
# Out:
# Empty DataFrame
# Columns: [image_file, result, path]
# Index: []

# %%
dataset = tf.keras.preprocessing.image_dataset_from_directory(
    "PlantVillage",
    
)
class_names = ['Potato___Early_blight', 'Potato___Late_blight', 'Potato___healthy']
plt.figure(figsize=(10, 10))
for image_batch, labels_batch in dataset.take(1):
    for i in range(12):
        ax = plt.subplot(3, 4, i + 1)
        plt.imshow(image_batch[i].numpy().astype("uint8"))
        plt.title(class_names[labels_batch[i]])
        plt.axis("off")
# Out:
# Found 2780 files belonging to 3 classes.

# %%
result_counts = data['result'].value_counts().reset_index()

plt.figure(figsize=(10, 6))
sns.barplot(x='index', y='result', data=result_counts)
plt.xticks(rotation=90)
plt.show()

# %%
print('Potato healthy ', list(data['result']).count('Potato___healthy'))
print('Potato___Late_blight : ', list(data['result']).count('Potato___Late_blight'))
print('Potato___Early_blight : ', list(data['result']).count('Potato___Early_blight'))

#10192 images sont normales
# Out:
# Potato healthy  760
# Potato___Late_blight :  1000
# Potato___Early_blight :  1020

# %%
round(data['result'].value_counts() / data.shape[0] * 100,2)
# Out:
# Potato___Early_blight    36.69
# Potato___Late_blight     35.97
# Potato___healthy         27.34
# Name: result, dtype: float64

# %% [markdown]
# # Classification using pixel feature extraction

# %%
pixel_img = []

for image in tqdm(data['path']):
    img=Image.open(image)
    img=ImageOps.grayscale(img)
    img=img.resize((64,64))
    img=np.asarray(img)
    img=img.reshape((64,64,1))
    pixel_img.append(img)
# Out:
# 100%|██████████| 2780/2780 [00:04<00:00, 603.36it/s]

# %%
pixel_img = np.array(pixel_img)
label_img = data['result'].map({'Potato___healthy': 0, 'Potato___Late_blight': 1, 'Potato___Early_blight' : 2})

print(pixel_img.shape, label_img.shape)
# Out:
# (2780, 64, 64, 1) (2780,)

# %%
X_train, X_test, y_train, y_test = train_test_split(pixel_img, label_img, 
                                                    test_size=0.2, stratify=label_img)
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (2224, 64, 64, 1)
# (556, 64, 64, 1)
# (2224,)
# (556,)

# %%
round(y_train.value_counts() / y_train.shape[0] * 100,2)
# Out:
# 2    36.69
# 1    35.97
# 0    27.34
# Name: result, dtype: float64

# %%
input_size = X_train.shape[1] * X_train.shape[2]
print(input_size)

num_classes = len(np.unique(y_train))
print(num_classes)
# Out:
# 4096
# 3

# %%
# flatten the image
X_train = np.reshape(X_train, [X_train.shape[0], input_size])
X_train = X_train.astype('float32') / 255

X_test = np.reshape(X_test, [X_test.shape[0], input_size])
X_test = X_test.astype('float32') / 255

# %% [markdown]
# * **Machine learning models**

# %%
# # confusion matrix and accuracy

# from sklearn import metrics
# from sklearn.metrics import classification_report 

# acc = accuracy_score(y_test, y_pred)
# print(f"Accuracy: {acc}")
# print(f"Classification report for classifier {nb_model}:\n"
#       f"{metrics.classification_report(y_test, y_pred)}\n")

# %%
# Create instances of the models
logistic_regression = LogisticRegression()
decision_tree = DecisionTreeClassifier()
random_forest = RandomForestClassifier()
svm_model = svm.SVC(kernel='rbf')
xgb_model = xgb.XGBClassifier(objective="binary:logistic", random_state=42)
kn_clas = KNeighborsClassifier()
log_reg = LogisticRegression()
nb_model = MultinomialNB()

# %%
# Train the models
logistic_regression.fit(X_train, y_train)
# Out:
# c:\Users\tejus\miniconda3\envs\myclone\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
decision_tree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
random_forest.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
xgb_model.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               objective='multi:softprob', predictor=None, ...)

# %%
kn_clas.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
nb_model.fit(X_train, y_train)
# Out:
# MultinomialNB()

# %%
svm_model.fit(X_train, y_train)
# Out:
# SVC()

# %%
# Obtain predictions from the models
logistic_regression_preds = logistic_regression.predict(X_test)
decision_tree_preds = decision_tree.predict(X_test)
random_forest_preds = random_forest.predict(X_test)
xgb_model_preds = xgb_model.predict(X_test)
kn_clas_preds = kn_clas.predict(X_test)
nb_model_preds = nb_model.predict(X_test)
svm_model_preds = svm_model.predict(X_test)

# %%
models = ['Logistic Regression', 'Decision Tree', 'Random Forest', 'xgb_model', 'kn_clas' , 'nb_model' , 'svm_model']
predictions = [logistic_regression_preds, decision_tree_preds, random_forest_preds, xgb_model_preds, kn_clas_preds, nb_model_preds , svm_model_preds]

# %%
report_df = pd.DataFrame(columns=['Model', 'Class', 'Precision', 'Recall', 'F1-Score', 'Support'])

# %%
for model, preds in zip(models, predictions):
    report = classification_report(y_test, preds, output_dict=True)
    
    for class_label, metrics in report.items():
        if class_label != 'accuracy':
            report_df = report_df.append({
                'Model': model,
                'Class': class_label,
                'Precision': metrics['precision'],
                'Recall': metrics['recall'],
                'F1-Score': metrics['f1-score'],
                'Support': metrics['support']
            }, ignore_index=True)
# Out:
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\750575445.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\750575445.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\750575445.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\750575445.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\750575445.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\750575445.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\750575445.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\750575445.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\750575445.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\750575445.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\750575445.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\750575445.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\750575445.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\750575445.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\750575445.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\750575445.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\750575445.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\750575445.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\750575445.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\750575445.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\750575445.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\750575445.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\750575445.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\750575445.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\750575445.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\750575445.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\750575445.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\750575445.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\750575445.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\750575445.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\750575445.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\750575445.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\750575445.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\750575445.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\750575445.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({

# %%
report_df
# Out:
#                   Model         Class  Precision    Recall  F1-Score Support
# 0   Logistic Regression             0   0.861272  0.980263  0.916923     152
# 1   Logistic Regression             1   0.816216  0.755000  0.784416     200
# 2   Logistic Regression             2   0.828283  0.803922  0.815920     204
# 3   Logistic Regression     macro avg   0.835257  0.846395  0.839086     556
# 4   Logistic Regression  weighted avg   0.832961  0.834532  0.832200     556
# 5         Decision Tree             0   0.863636  1.000000  0.926829     152
# 6         Decision Tree             1   0.787565  0.760000  0.773537     200
# 7         Decision Tree             2   0.844920  0.774510  0.808184     204
# 8         Decision Tree     macro avg   0.832040  0.844837  0.836183     556
# 9         Decision Tree  weighted avg   0.829405  0.830935  0.828156     556
# 10        Random Forest             0   0.974359  1.000000  0.987013     152
# 11        Random Forest             1   0.928205  0.905000  0.916456     200
# 12        Random Forest             2   0.926829  0.931373  0.929095     204
# 13        Random Forest     macro avg   0.943131  0.945458  0.944188     556
# 14        Random Forest  weighted avg   0.940318  0.940647  0.940382     556
# 15            xgb_model             0   0.980645  1.000000  0.990228     152
# 16            xgb_model             1   0.939394  0.930000  0.934673     200
# 17            xgb_model             2   0.945813  0.941176  0.943489     204
# 18            xgb_model     macro avg   0.955284  0.957059  0.956130     556
# 19            xgb_model  weighted avg   0.953026  0.953237  0.953095     556
# 20              kn_clas             0   0.695431  0.901316  0.785100     152
# 21              kn_clas             1   0.630037  0.860000  0.727273     200
# 22              kn_clas             2   1.000000  0.421569  0.593103     204
# 23              kn_clas     macro avg   0.775156  0.727628  0.701825     556
# 24              kn_clas  weighted avg   0.783656  0.710432  0.693854     556
# 25             nb_model             0   0.587413  0.552632  0.569492     152
# 26             nb_model             1   0.593301  0.620000  0.606357     200
# 27             nb_model             2   0.789216  0.789216  0.789216     204
# 28             nb_model     macro avg   0.656643  0.653949  0.655021     556
# 29             nb_model  weighted avg   0.663574  0.663669  0.663371     556
# 30            svm_model             0   0.903030  0.980263  0.940063     152
# 31            svm_model             1   0.951872  0.890000  0.919897     200
# 32            svm_model             2   0.965686  0.965686  0.965686     204
# 33            svm_model     macro avg   0.940196  0.945316  0.941882     556
# 34            svm_model  weighted avg   0.943588  0.942446  0.942210     556

# %%
import pandas as pd
from sklearn.metrics import classification_report, accuracy_score

report_df = pd.DataFrame(columns=['Accuracy', 'Model', 'Class', 'Precision', 'Recall', 'F1-Score', 'Support'])
models = ['Logistic Regression', 'Decision Tree', 'Random Forest', 'xgb_model', 'kn_clas', 'nb_model', 'svm_model']
predictions = [logistic_regression_preds, decision_tree_preds, random_forest_preds, xgb_model_preds, kn_clas_preds, nb_model_preds, svm_model_preds]
y_true = y_test  # Assuming y_test is the true labels

for model, preds in zip(models, predictions):
    accuracy = accuracy_score(y_true, preds)
    report = classification_report(y_true, preds, output_dict=True)

    overall_precision = report['macro avg']['precision']
    overall_recall = report['macro avg']['recall']
    overall_f1_score = report['macro avg']['f1-score']

    overall_support = sum(1 for true_label, pred_label in zip(y_true, preds) if true_label == pred_label)

    for class_label, metrics in report.items():
        if class_label == 'accuracy':
            report_df = report_df.append({
                'Accuracy': accuracy,
                'Model': model,
                'Class': 'Overall',
                'Precision': overall_precision,
                'Recall': overall_recall,
                'F1-Score': overall_f1_score,
                'Support': overall_support,
            }, ignore_index=True)
        else:
            report_df = report_df.append({
                'Accuracy': accuracy,
                'Model': model,
                'Class': class_label,
                'Precision': metrics['precision'],
                'Recall': metrics['recall'],
                'F1-Score': metrics['f1-score'],
                'Support': metrics['support'],
            }, ignore_index=True)
# Out:
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({

# %%
report_df
# Out:
#     Accuracy                Model         Class  Precision    Recall  \
# 0   0.834532  Logistic Regression             0   0.861272  0.980263
# 1   0.834532  Logistic Regression             1   0.816216  0.755000
# 2   0.834532  Logistic Regression             2   0.828283  0.803922
# 3   0.834532  Logistic Regression       Overall   0.835257  0.846395
# 4   0.834532  Logistic Regression     macro avg   0.835257  0.846395
# 5   0.834532  Logistic Regression  weighted avg   0.832961  0.834532
# 6   0.830935        Decision Tree             0   0.863636  1.000000
# 7   0.830935        Decision Tree             1   0.787565  0.760000
# 8   0.830935        Decision Tree             2   0.844920  0.774510
# 9   0.830935        Decision Tree       Overall   0.832040  0.844837
# 10  0.830935        Decision Tree     macro avg   0.832040  0.844837
# 11  0.830935        Decision Tree  weighted avg   0.829405  0.830935
# 12  0.940647        Random Forest             0   0.974359  1.000000
# 13  0.940647        Random Forest             1   0.928205  0.905000
# 14  0.940647        Random Forest             2   0.926829  0.931373
# 15  0.940647        Random Forest       Overall   0.943131  0.945458
# 16  0.940647        Random Forest     macro avg   0.943131  0.945458
# 17  0.940647        Random Forest  weighted avg   0.940318  0.940647
# 18  0.953237            xgb_model             0   0.980645  1.000000
# 19  0.953237            xgb_model             1   0.939394  0.930000
# 20  0.953237            xgb_model             2   0.945813  0.941176
# 21  0.953237            xgb_model       Overall   0.955284  0.957059
# 22  0.953237            xgb_model     macro avg   0.955284  0.957059
# 23  0.953237            xgb_model  weighted avg   0.953026  0.953237
# 24  0.710432              kn_clas             0   0.695431  0.901316
# 25  0.710432              kn_clas             1   0.630037  0.860000
# 26  0.710432              kn_clas             2   1.000000  0.421569
# 27  0.710432              kn_clas       Overall   0.775156  0.727628
# 28  0.710432              kn_clas     macro avg   0.775156  0.727628
# 29  0.710432              kn_clas  weighted avg   0.783656  0.710432
# 30  0.663669             nb_model             0   0.587413  0.552632
# 31  0.663669             nb_model             1   0.593301  0.620000
# 32  0.663669             nb_model             2   0.789216  0.789216
# 33  0.663669             nb_model       Overall   0.656643  0.653949
# 34  0.663669             nb_model     macro avg   0.656643  0.653949
# 35  0.663669             nb_model  weighted avg   0.663574  0.663669
# 36  0.942446            svm_model             0   0.903030  0.980263
# 37  0.942446            svm_model             1   0.951872  0.890000
# 38  0.942446            svm_model             2   0.965686  0.965686
# 39  0.942446            svm_model       Overall   0.940196  0.945316
# 40  0.942446            svm_model     macro avg   0.940196  0.945316
# 41  0.942446            svm_model  weighted avg   0.943588  0.942446
#
#     F1-Score Support
# 0   0.916923     152
# 1   0.784416     200
# 2   0.815920     204
# 3   0.839086     464
# 4   0.839086     556
# 5   0.832200     556
# 6   0.926829     152
# 7   0.773537     200
# 8   0.808184     204
# 9   0.836183     462
# 10  0.836183     556
# 11  0.828156     556
# 12  0.987013     152
# 13  0.916456     200
# 14  0.929095     204
# 15  0.944188     523
# 16  0.944188     556
# 17  0.940382     556
# 18  0.990228     152
# 19  0.934673     200
# 20  0.943489     204
# 21  0.956130     530
# 22  0.956130     556
# 23  0.953095     556
# 24  0.785100     152
# 25  0.727273     200
# 26  0.593103     204
# 27  0.701825     395
# 28  0.701825     556
# 29  0.693854     556
# 30  0.569492     152
# 31  0.606357     200
# 32  0.789216     204
# 33  0.655021     369
# 34  0.655021     556
# 35  0.663371     556
# 36  0.940063     152
# 37  0.919897     200
# 38  0.965686     204
# 39  0.941882     524
# 40  0.941882     556
# 41  0.942210     556

# %%
import matplotlib.pyplot as plt
import numpy as np

# Get unique class names and models
class_names = report_df['Class'].unique()
model_names = report_df['Model'].unique()

# Set the number of classes and models
num_classes = len(class_names)
num_models = len(model_names)

# Set the width of each bar
bar_width = 0.8

# Set the positions of the bars on the x-axis
positions = np.arange(num_classes)

# Set the colors for the models
colors = ['red', 'blue', 'green', 'orange', 'purple']

# Create a dictionary to store the F1-Scores for each class
f1_scores_by_class = {class_name: [] for class_name in class_names}

# Iterate over each row in the dataframe
for _, row in report_df.iterrows():
    class_name = row['Class']
    f1_score = row['F1-Score']
    f1_scores_by_class[class_name].append(f1_score)

# Plot the F1-Scores for each class and model using a grouped bar plot
plt.figure(figsize=(10, 6))

# Iterate over each model
for i, model_name in enumerate(model_names):
    # Get the F1-Scores for the current model
    f1_scores = [f1_scores_by_class[class_name][i] for class_name in class_names]
    # Get the color for the current model
    color = colors[i % len(colors)]
    # Calculate the positions for the current model
    current_positions = positions + (i - num_models / 2 + 0.5) * bar_width / num_models
    # Plot the bars for the current model
    plt.bar(current_positions, f1_scores, width=bar_width / num_models, label=model_name, color=color)

plt.xlabel('Class')
plt.ylabel('F1-Score')
plt.title('F1-Score Comparison by Class and Model[SIFT]')
plt.xticks(positions, class_names)
plt.legend(title='Model')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming your DataFrame is named report_df
plt.figure(figsize=(12, 6))
sns.barplot(x='Model', y='Accuracy', data=report_df, ci=None)
plt.xticks(rotation=45)
plt.xlabel('Model')
plt.ylabel('Accuracy')
plt.title('Accuracy vs. Model')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\2650676806.py:6: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='Model', y='Accuracy', data=report_df, ci=None)

# %% [markdown]
# # Classification using IBP feature extration

# %%
data['path'][0]
# Out:
# 'C:\\Users\\tejus\\Desktop\\shannu potato\\PlantVillage/Potato___Early_blight/001187a0-57ab-4329-baff-e7246a9edeb0___RS_Early.B 8178.JPG'

# %%
# Function to extract LBP features from an image
def extract_lbp_features(image):
    gray = np.array(image)
    lbp = local_binary_pattern(gray, 8, 1, method='uniform')
    hist, _ = np.histogram(lbp.ravel(), bins=np.arange(0, 60), range=(0, 59))
    return hist

# %%
def process_images():
    features = []
    for filename in tqdm(data['path']):
        if filename.endswith('.JPG') or filename.endswith('.png'):
            img = Image.open(filename)
            img = ImageOps.grayscale(img)
            img = img.resize((64, 64))
            lbp_features = extract_lbp_features(img)
            features.append(lbp_features)
            #print(len(features))
    return features

# %%
from skimage.feature import local_binary_pattern


lbp_features = process_images()
lbp_features = np.array(lbp_features)
np.save('lbp_features.npy', lbp_features)
# Out:
# 100%|██████████| 2780/2780 [00:09<00:00, 296.45it/s]

# %%
lbp_features = np.load('lbp_features.npy')

# %%
len(lbp_features)
# Out:
# 2780

# %%
pixel_img = np.array(pixel_img)
label_img = data['result'].map({'Potato___healthy': 0, 'Potato___Late_blight': 1, 'Potato___Early_blight' : 2})

print(pixel_img.shape, label_img.shape)
# Out:
# (2780, 64, 64, 1) (2780,)

# %%
print(lbp_features.shape)
print(label_img.shape)
# Out:
# (2780, 59)
# (2780,)

# %%
X_train, X_test, y_train, y_test = train_test_split(lbp_features, label_img, 
                                                    test_size=0.2, stratify=label_img)
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (2224, 59)
# (556, 59)
# (2224,)
# (556,)

# %%
round(y_train.value_counts() / y_train.shape[0] * 100,2)
# Out:
# 2    36.69
# 1    35.97
# 0    27.34
# Name: result, dtype: float64

# %%
# Create instances of the models
logistic_regression = LogisticRegression()
decision_tree = DecisionTreeClassifier()
random_forest = RandomForestClassifier()
svm_model = svm.SVC(kernel='rbf')
xgb_model = xgb.XGBClassifier(objective="binary:logistic", random_state=42)
kn_clas = KNeighborsClassifier()
log_reg = LogisticRegression()
nb_model = MultinomialNB()

# %%
# Train the models
logistic_regression.fit(X_train, y_train)
# Out:
# c:\Users\tejus\miniconda3\envs\myclone\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
decision_tree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
random_forest.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
xgb_model.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               objective='multi:softprob', predictor=None, ...)

# %%
kn_clas.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
nb_model.fit(X_train, y_train)
# Out:
# MultinomialNB()

# %%
svm_model.fit(X_train, y_train)
# Out:
# SVC()

# %%
# Obtain predictions from the models
logistic_regression_preds = logistic_regression.predict(X_test)
decision_tree_preds = decision_tree.predict(X_test)
random_forest_preds = random_forest.predict(X_test)
xgb_model_preds = xgb_model.predict(X_test)
kn_clas_preds = kn_clas.predict(X_test)
nb_model_preds = nb_model.predict(X_test)
svm_model_preds = svm_model.predict(X_test)

# %%
models = ['Logistic Regression', 'Decision Tree', 'Random Forest', 'xgb_model', 'kn_clas' , 'nb_model' , 'svm_model']
predictions = [logistic_regression_preds, decision_tree_preds, random_forest_preds, xgb_model_preds, kn_clas_preds, nb_model_preds , svm_model_preds]

# %%
report_df = pd.DataFrame(columns=['Model', 'Class', 'Precision', 'Recall', 'F1-Score', 'Support'])

# %%
for model, preds in zip(models, predictions):
    report = classification_report(y_test, preds, output_dict=True)
    
    for class_label, metrics in report.items():
        if class_label != 'accuracy':
            report_df = report_df.append({
                'Model': model,
                'Class': class_label,
                'Precision': metrics['precision'],
                'Recall': metrics['recall'],
                'F1-Score': metrics['f1-score'],
                'Support': metrics['support']
            }, ignore_index=True)
# Out:
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\2844835500.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\2844835500.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\2844835500.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\2844835500.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\2844835500.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\2844835500.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\2844835500.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\2844835500.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\2844835500.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\2844835500.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\2844835500.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\2844835500.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\2844835500.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\2844835500.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\2844835500.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\2844835500.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\2844835500.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\2844835500.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\2844835500.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\2844835500.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\2844835500.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\2844835500.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\2844835500.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\2844835500.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\2844835500.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\2844835500.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\2844835500.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\2844835500.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\2844835500.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\2844835500.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\2844835500.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\2844835500.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\2844835500.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\2844835500.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\2844835500.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({

# %%
report_df
# Out:
#                   Model         Class  Precision    Recall  F1-Score Support
# 0   Logistic Regression             0   0.824324  0.802632  0.813333     152
# 1   Logistic Regression             1   0.676617  0.680000  0.678304     200
# 2   Logistic Regression             2   0.719807  0.730392  0.725061     204
# 3   Logistic Regression     macro avg   0.740249  0.737675  0.738899     556
# 4   Logistic Regression  weighted avg   0.732844  0.732014  0.732374     556
# 5         Decision Tree             0   0.899408  1.000000  0.947040     152
# 6         Decision Tree             1   0.677249  0.640000  0.658098     200
# 7         Decision Tree             2   0.676768  0.656863  0.666667     204
# 8         Decision Tree     macro avg   0.751142  0.765621  0.757268     556
# 9         Decision Tree  weighted avg   0.737806  0.744604  0.740233     556
# 10        Random Forest             0   0.921212  1.000000  0.958991     152
# 11        Random Forest             1   0.740385  0.770000  0.754902     200
# 12        Random Forest             2   0.775956  0.696078  0.733850     204
# 13        Random Forest     macro avg   0.812518  0.822026  0.815914     556
# 14        Random Forest  weighted avg   0.802871  0.805755  0.802972     556
# 15            xgb_model             0   0.915663  1.000000  0.955975     152
# 16            xgb_model             1   0.734694  0.720000  0.727273     200
# 17            xgb_model             2   0.752577  0.715686  0.733668     204
# 18            xgb_model     macro avg   0.800978  0.811895  0.805639     556
# 19            xgb_model  weighted avg   0.790729  0.794964  0.792142     556
# 20              kn_clas             0   0.805405  0.980263  0.884273     152
# 21              kn_clas             1   0.728324  0.630000  0.675603     200
# 22              kn_clas             2   0.717172  0.696078  0.706468     204
# 23              kn_clas     macro avg   0.750300  0.768781  0.755448     556
# 24              kn_clas  weighted avg   0.745305  0.750000  0.743974     556
# 25             nb_model             0   0.706522  0.855263  0.773810     152
# 26             nb_model             1   0.626316  0.595000  0.610256     200
# 27             nb_model             2   0.703297  0.627451  0.663212     204
# 28             nb_model     macro avg   0.678711  0.692571  0.682426     556
# 29             nb_model  weighted avg   0.676487  0.678058  0.674399     556
# 30            svm_model             0   0.817568  0.796053  0.806667     152
# 31            svm_model             1   0.638095  0.670000  0.653659     200
# 32            svm_model             2   0.702020  0.681373  0.691542     204
# 33            svm_model     macro avg   0.719228  0.715808  0.717289     556
# 34            svm_model  weighted avg   0.710614  0.708633  0.709388     556

# %%
import pandas as pd
from sklearn.metrics import classification_report, accuracy_score

report_df = pd.DataFrame(columns=['Accuracy', 'Model', 'Class', 'Precision', 'Recall', 'F1-Score', 'Support'])
models = ['Logistic Regression', 'Decision Tree', 'Random Forest', 'xgb_model', 'kn_clas', 'nb_model', 'svm_model']
predictions = [logistic_regression_preds, decision_tree_preds, random_forest_preds, xgb_model_preds, kn_clas_preds, nb_model_preds, svm_model_preds]
y_true = y_test  # Assuming y_test is the true labels

for model, preds in zip(models, predictions):
    accuracy = accuracy_score(y_true, preds)
    report = classification_report(y_true, preds, output_dict=True)

    overall_precision = report['macro avg']['precision']
    overall_recall = report['macro avg']['recall']
    overall_f1_score = report['macro avg']['f1-score']

    overall_support = sum(1 for true_label, pred_label in zip(y_true, preds) if true_label == pred_label)

    for class_label, metrics in report.items():
        if class_label == 'accuracy':
            report_df = report_df.append({
                'Accuracy': accuracy,
                'Model': model,
                'Class': 'Overall',
                'Precision': overall_precision,
                'Recall': overall_recall,
                'F1-Score': overall_f1_score,
                'Support': overall_support,
            }, ignore_index=True)
        else:
            report_df = report_df.append({
                'Accuracy': accuracy,
                'Model': model,
                'Class': class_label,
                'Precision': metrics['precision'],
                'Recall': metrics['recall'],
                'F1-Score': metrics['f1-score'],
                'Support': metrics['support'],
            }, ignore_index=True)
# Out:
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({

# %%
report_df
# Out:
#     Accuracy                Model         Class  Precision    Recall  \
# 0   0.732014  Logistic Regression             0   0.824324  0.802632
# 1   0.732014  Logistic Regression             1   0.676617  0.680000
# 2   0.732014  Logistic Regression             2   0.719807  0.730392
# 3   0.732014  Logistic Regression       Overall   0.740249  0.737675
# 4   0.732014  Logistic Regression     macro avg   0.740249  0.737675
# 5   0.732014  Logistic Regression  weighted avg   0.732844  0.732014
# 6   0.744604        Decision Tree             0   0.899408  1.000000
# 7   0.744604        Decision Tree             1   0.677249  0.640000
# 8   0.744604        Decision Tree             2   0.676768  0.656863
# 9   0.744604        Decision Tree       Overall   0.751142  0.765621
# 10  0.744604        Decision Tree     macro avg   0.751142  0.765621
# 11  0.744604        Decision Tree  weighted avg   0.737806  0.744604
# 12  0.805755        Random Forest             0   0.921212  1.000000
# 13  0.805755        Random Forest             1   0.740385  0.770000
# 14  0.805755        Random Forest             2   0.775956  0.696078
# 15  0.805755        Random Forest       Overall   0.812518  0.822026
# 16  0.805755        Random Forest     macro avg   0.812518  0.822026
# 17  0.805755        Random Forest  weighted avg   0.802871  0.805755
# 18  0.794964            xgb_model             0   0.915663  1.000000
# 19  0.794964            xgb_model             1   0.734694  0.720000
# 20  0.794964            xgb_model             2   0.752577  0.715686
# 21  0.794964            xgb_model       Overall   0.800978  0.811895
# 22  0.794964            xgb_model     macro avg   0.800978  0.811895
# 23  0.794964            xgb_model  weighted avg   0.790729  0.794964
# 24  0.750000              kn_clas             0   0.805405  0.980263
# 25  0.750000              kn_clas             1   0.728324  0.630000
# 26  0.750000              kn_clas             2   0.717172  0.696078
# 27  0.750000              kn_clas       Overall   0.750300  0.768781
# 28  0.750000              kn_clas     macro avg   0.750300  0.768781
# 29  0.750000              kn_clas  weighted avg   0.745305  0.750000
# 30  0.678058             nb_model             0   0.706522  0.855263
# 31  0.678058             nb_model             1   0.626316  0.595000
# 32  0.678058             nb_model             2   0.703297  0.627451
# 33  0.678058             nb_model       Overall   0.678711  0.692571
# 34  0.678058             nb_model     macro avg   0.678711  0.692571
# 35  0.678058             nb_model  weighted avg   0.676487  0.678058
# 36  0.708633            svm_model             0   0.817568  0.796053
# 37  0.708633            svm_model             1   0.638095  0.670000
# 38  0.708633            svm_model             2   0.702020  0.681373
# 39  0.708633            svm_model       Overall   0.719228  0.715808
# 40  0.708633            svm_model     macro avg   0.719228  0.715808
# 41  0.708633            svm_model  weighted avg   0.710614  0.708633
#
#     F1-Score Support
# 0   0.813333     152
# 1   0.678304     200
# 2   0.725061     204
# 3   0.738899     407
# 4   0.738899     556
# 5   0.732374     556
# 6   0.947040     152
# 7   0.658098     200
# 8   0.666667     204
# 9   0.757268     414
# 10  0.757268     556
# 11  0.740233     556
# 12  0.958991     152
# 13  0.754902     200
# 14  0.733850     204
# 15  0.815914     448
# 16  0.815914     556
# 17  0.802972     556
# 18  0.955975     152
# 19  0.727273     200
# 20  0.733668     204
# 21  0.805639     442
# 22  0.805639     556
# 23  0.792142     556
# 24  0.884273     152
# 25  0.675603     200
# 26  0.706468     204
# 27  0.755448     417
# 28  0.755448     556
# 29  0.743974     556
# 30  0.773810     152
# 31  0.610256     200
# 32  0.663212     204
# 33  0.682426     377
# 34  0.682426     556
# 35  0.674399     556
# 36  0.806667     152
# 37  0.653659     200
# 38  0.691542     204
# 39  0.717289     394
# 40  0.717289     556
# 41  0.709388     556

# %%
import matplotlib.pyplot as plt
import numpy as np

# Get unique class names and models
class_names = report_df['Class'].unique()
model_names = report_df['Model'].unique()

# Set the number of classes and models
num_classes = len(class_names)
num_models = len(model_names)

# Set the width of each bar
bar_width = 0.8

# Set the positions of the bars on the x-axis
positions = np.arange(num_classes)

# Set the colors for the models
colors = ['red', 'blue', 'green', 'orange', 'purple']

# Create a dictionary to store the F1-Scores for each class
f1_scores_by_class = {class_name: [] for class_name in class_names}

# Iterate over each row in the dataframe
for _, row in report_df.iterrows():
    class_name = row['Class']
    f1_score = row['F1-Score']
    f1_scores_by_class[class_name].append(f1_score)

# Plot the F1-Scores for each class and model using a grouped bar plot
plt.figure(figsize=(10, 6))

# Iterate over each model
for i, model_name in enumerate(model_names):
    # Get the F1-Scores for the current model
    f1_scores = [f1_scores_by_class[class_name][i] for class_name in class_names]
    # Get the color for the current model
    color = colors[i % len(colors)]
    # Calculate the positions for the current model
    current_positions = positions + (i - num_models / 2 + 0.5) * bar_width / num_models
    # Plot the bars for the current model
    plt.bar(current_positions, f1_scores, width=bar_width / num_models, label=model_name, color=color)

plt.xlabel('Class')
plt.ylabel('F1-Score')
plt.title('F1-Score Comparison by Class and Model')
plt.xticks(positions, class_names)
plt.legend(title='Model')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming your DataFrame is named report_df
plt.figure(figsize=(12, 6))
sns.barplot(x='Model', y='Accuracy', data=report_df, ci=None)
plt.xticks(rotation=45)
plt.xlabel('Model')
plt.ylabel('Accuracy')
plt.title('Accuracy vs. Model')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\2650676806.py:6: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='Model', y='Accuracy', data=report_df, ci=None)

# %% [markdown]
# # Classification using HOG feature extration

# %%
# Function to extract Hog features from an image
from skimage.feature import hog
def extract_hog_features(image):
    # Convert image to grayscale
    gray = np.array(image)
    
    # Compute HOG features
    features = hog(gray, orientations=9, pixels_per_cell=(8, 8),
                   cells_per_block=(2, 2), transform_sqrt=True,
                   block_norm='L2-Hys')

    return features

# %%
# Function to process all images in a directory and extract SIFT features
def process_images():
    features = []
    for filename in tqdm(data['path']):
        if filename.endswith('.JPG') or filename.endswith('.png'):
            img = Image.open(filename)
            img = ImageOps.grayscale(img)
            img = img.resize((64, 64))
            Hog_features = extract_hog_features(img)
            features.append(Hog_features)
    
    return features

# %%
class_directory = '/kaggle/working/'
class_2_features = process_images()
np.save('class_2_features.npy', class_2_features)
# Out:
# 100%|██████████| 2780/2780 [00:13<00:00, 210.07it/s]

# %%
class_2_features = np.load('class_2_features.npy')

# %%
label_img = data['result'].map({'Potato___healthy': 0, 'Potato___Late_blight': 1, 'Potato___Early_blight' : 2})

# %%
print(class_2_features.shape, label_img.shape)
# Out:
# (2780, 1764) (2780,)

# %%
# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(class_2_features, label_img, 
                                                    test_size=0.2, stratify=label_img)
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (2224, 1764)
# (556, 1764)
# (2224,)
# (556,)

# %%
round(y_train.value_counts() / y_train.shape[0] * 100,2)
# Out:
# 2    36.69
# 1    35.97
# 0    27.34
# Name: result, dtype: float64

# %% [markdown]
# **machine learning model**

# %%
# Create instances of the models
logistic_regression = LogisticRegression()
decision_tree = DecisionTreeClassifier()
random_forest = RandomForestClassifier()
svm_model = svm.SVC(kernel='rbf')
xgb_model = xgb.XGBClassifier(objective="binary:logistic", random_state=42)
kn_clas = KNeighborsClassifier()
log_reg = LogisticRegression()
nb_model = MultinomialNB()

# %%
# Train the models
logistic_regression.fit(X_train, y_train)
# Out:
# c:\Users\tejus\miniconda3\envs\myclone\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
decision_tree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
random_forest.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
xgb_model.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               objective='multi:softprob', predictor=None, ...)

# %%
kn_clas.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
nb_model.fit(X_train, y_train)
# Out:
# MultinomialNB()

# %%
svm_model.fit(X_train, y_train)
# Out:
# SVC()

# %%
# Obtain predictions from the models
logistic_regression_preds = logistic_regression.predict(X_test)
decision_tree_preds = decision_tree.predict(X_test)
random_forest_preds = random_forest.predict(X_test)
xgb_model_preds = xgb_model.predict(X_test)
kn_clas_preds = kn_clas.predict(X_test)
nb_model_preds = nb_model.predict(X_test)
svm_model_preds = svm_model.predict(X_test)

# %%
models = ['Logistic Regression', 'Decision Tree', 'Random Forest', 'xgb_model', 'kn_clas' , 'nb_model' , 'svm_model']
predictions = [logistic_regression_preds, decision_tree_preds, random_forest_preds, xgb_model_preds, kn_clas_preds, nb_model_preds , svm_model_preds]

# %%
report_df = pd.DataFrame(columns=['Model', 'Class', 'Precision', 'Recall', 'F1-Score', 'Support'])

# %%
for model, preds in zip(models, predictions):
    report = classification_report(y_test, preds, output_dict=True)
    
    for class_label, metrics in report.items():
        if class_label != 'accuracy':
            report_df = report_df.append({
                'Model': model,
                'Class': class_label,
                'Precision': metrics['precision'],
                'Recall': metrics['recall'],
                'F1-Score': metrics['f1-score'],
                'Support': metrics['support']
            }, ignore_index=True)
# Out:
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\750575445.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\750575445.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\750575445.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\750575445.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\750575445.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\750575445.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\750575445.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\750575445.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\750575445.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\750575445.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\750575445.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\750575445.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\750575445.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\750575445.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\750575445.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\750575445.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\750575445.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\750575445.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\750575445.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\750575445.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\750575445.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\750575445.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\750575445.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\750575445.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\750575445.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\750575445.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\750575445.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\750575445.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\750575445.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\750575445.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\750575445.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\750575445.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\750575445.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\750575445.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\750575445.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({

# %%
report_df
# Out:
#                   Model         Class  Precision    Recall  F1-Score Support
# 0   Logistic Regression             0   0.873563  1.000000  0.932515     152
# 1   Logistic Regression             1   0.878453  0.795000  0.834646     200
# 2   Logistic Regression             2   0.895522  0.882353  0.888889     204
# 3   Logistic Regression     macro avg   0.882513  0.892451  0.885350     556
# 4   Logistic Regression  weighted avg   0.883379  0.883094  0.881304     556
# 5         Decision Tree             0   0.849162  1.000000  0.918429     152
# 6         Decision Tree             1   0.635220  0.505000  0.562674     200
# 7         Decision Tree             2   0.619266  0.661765  0.639810     204
# 8         Decision Tree     macro avg   0.701216  0.722255  0.706971     556
# 9         Decision Tree  weighted avg   0.687854  0.697842  0.688233     556
# 10        Random Forest             0   1.000000  1.000000  1.000000     152
# 11        Random Forest             1   0.841584  0.850000  0.845771     200
# 12        Random Forest             2   0.851485  0.843137  0.847291     204
# 13        Random Forest     macro avg   0.897690  0.897712  0.897687     556
# 14        Random Forest  weighted avg   0.888525  0.888489  0.888492     556
# 15            xgb_model             0   1.000000  1.000000  1.000000     152
# 16            xgb_model             1   0.916230  0.875000  0.895141     200
# 17            xgb_model             2   0.882629  0.921569  0.901679     204
# 18            xgb_model     macro avg   0.932953  0.932190  0.932273     556
# 19            xgb_model  weighted avg   0.926803  0.926259  0.926206     556
# 20              kn_clas             0   0.656388  0.980263  0.786280     152
# 21              kn_clas             1   0.804878  0.660000  0.725275     200
# 22              kn_clas             2   0.921212  0.745098  0.823848     204
# 23              kn_clas     macro avg   0.794159  0.795120  0.778468     556
# 24              kn_clas  weighted avg   0.806967  0.778777  0.778120     556
# 25             nb_model             0   0.678571  0.625000  0.650685     152
# 26             nb_model             1   0.585586  0.650000  0.616114     200
# 27             nb_model             2   0.747423  0.710784  0.728643     204
# 28             nb_model     macro avg   0.670527  0.661928  0.665147     556
# 29             nb_model  weighted avg   0.670385  0.665468  0.666853     556
# 30            svm_model             0   0.974359  1.000000  0.987013     152
# 31            svm_model             1   0.909548  0.905000  0.907268     200
# 32            svm_model             2   0.925373  0.911765  0.918519     204
# 33            svm_model     macro avg   0.936427  0.938922  0.937600     556
# 34            svm_model  weighted avg   0.933072  0.933453  0.933197     556

# %%
import pandas as pd
from sklearn.metrics import classification_report, accuracy_score

report_df = pd.DataFrame(columns=['Accuracy', 'Model', 'Class', 'Precision', 'Recall', 'F1-Score', 'Support'])
models = ['Logistic Regression', 'Decision Tree', 'Random Forest', 'xgb_model', 'kn_clas', 'nb_model', 'svm_model']
predictions = [logistic_regression_preds, decision_tree_preds, random_forest_preds, xgb_model_preds, kn_clas_preds, nb_model_preds, svm_model_preds]
y_true = y_test  # Assuming y_test is the true labels

for model, preds in zip(models, predictions):
    accuracy = accuracy_score(y_true, preds)
    report = classification_report(y_true, preds, output_dict=True)

    overall_precision = report['macro avg']['precision']
    overall_recall = report['macro avg']['recall']
    overall_f1_score = report['macro avg']['f1-score']

    overall_support = sum(1 for true_label, pred_label in zip(y_true, preds) if true_label == pred_label)

    for class_label, metrics in report.items():
        if class_label == 'accuracy':
            report_df = report_df.append({
                'Accuracy': accuracy,
                'Model': model,
                'Class': 'Overall',
                'Precision': overall_precision,
                'Recall': overall_recall,
                'F1-Score': overall_f1_score,
                'Support': overall_support,
            }, ignore_index=True)
        else:
            report_df = report_df.append({
                'Accuracy': accuracy,
                'Model': model,
                'Class': class_label,
                'Precision': metrics['precision'],
                'Recall': metrics['recall'],
                'F1-Score': metrics['f1-score'],
                'Support': metrics['support'],
            }, ignore_index=True)
# Out:
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\193115443.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   report_df = report_df.append({

# %%
report_df
# Out:
#     Accuracy                Model         Class  Precision    Recall  \
# 0   0.883094  Logistic Regression             0   0.873563  1.000000
# 1   0.883094  Logistic Regression             1   0.878453  0.795000
# 2   0.883094  Logistic Regression             2   0.895522  0.882353
# 3   0.883094  Logistic Regression       Overall   0.882513  0.892451
# 4   0.883094  Logistic Regression     macro avg   0.882513  0.892451
# 5   0.883094  Logistic Regression  weighted avg   0.883379  0.883094
# 6   0.697842        Decision Tree             0   0.849162  1.000000
# 7   0.697842        Decision Tree             1   0.635220  0.505000
# 8   0.697842        Decision Tree             2   0.619266  0.661765
# 9   0.697842        Decision Tree       Overall   0.701216  0.722255
# 10  0.697842        Decision Tree     macro avg   0.701216  0.722255
# 11  0.697842        Decision Tree  weighted avg   0.687854  0.697842
# 12  0.888489        Random Forest             0   1.000000  1.000000
# 13  0.888489        Random Forest             1   0.841584  0.850000
# 14  0.888489        Random Forest             2   0.851485  0.843137
# 15  0.888489        Random Forest       Overall   0.897690  0.897712
# 16  0.888489        Random Forest     macro avg   0.897690  0.897712
# 17  0.888489        Random Forest  weighted avg   0.888525  0.888489
# 18  0.926259            xgb_model             0   1.000000  1.000000
# 19  0.926259            xgb_model             1   0.916230  0.875000
# 20  0.926259            xgb_model             2   0.882629  0.921569
# 21  0.926259            xgb_model       Overall   0.932953  0.932190
# 22  0.926259            xgb_model     macro avg   0.932953  0.932190
# 23  0.926259            xgb_model  weighted avg   0.926803  0.926259
# 24  0.778777              kn_clas             0   0.656388  0.980263
# 25  0.778777              kn_clas             1   0.804878  0.660000
# 26  0.778777              kn_clas             2   0.921212  0.745098
# 27  0.778777              kn_clas       Overall   0.794159  0.795120
# 28  0.778777              kn_clas     macro avg   0.794159  0.795120
# 29  0.778777              kn_clas  weighted avg   0.806967  0.778777
# 30  0.665468             nb_model             0   0.678571  0.625000
# 31  0.665468             nb_model             1   0.585586  0.650000
# 32  0.665468             nb_model             2   0.747423  0.710784
# 33  0.665468             nb_model       Overall   0.670527  0.661928
# 34  0.665468             nb_model     macro avg   0.670527  0.661928
# 35  0.665468             nb_model  weighted avg   0.670385  0.665468
# 36  0.933453            svm_model             0   0.974359  1.000000
# 37  0.933453            svm_model             1   0.909548  0.905000
# 38  0.933453            svm_model             2   0.925373  0.911765
# 39  0.933453            svm_model       Overall   0.936427  0.938922
# 40  0.933453            svm_model     macro avg   0.936427  0.938922
# 41  0.933453            svm_model  weighted avg   0.933072  0.933453
#
#     F1-Score Support
# 0   0.932515     152
# 1   0.834646     200
# 2   0.888889     204
# 3   0.885350     491
# 4   0.885350     556
# 5   0.881304     556
# 6   0.918429     152
# 7   0.562674     200
# 8   0.639810     204
# 9   0.706971     388
# 10  0.706971     556
# 11  0.688233     556
# 12  1.000000     152
# 13  0.845771     200
# 14  0.847291     204
# 15  0.897687     494
# 16  0.897687     556
# 17  0.888492     556
# 18  1.000000     152
# 19  0.895141     200
# 20  0.901679     204
# 21  0.932273     515
# 22  0.932273     556
# 23  0.926206     556
# 24  0.786280     152
# 25  0.725275     200
# 26  0.823848     204
# 27  0.778468     433
# 28  0.778468     556
# 29  0.778120     556
# 30  0.650685     152
# 31  0.616114     200
# 32  0.728643     204
# 33  0.665147     370
# 34  0.665147     556
# 35  0.666853     556
# 36  0.987013     152
# 37  0.907268     200
# 38  0.918519     204
# 39  0.937600     519
# 40  0.937600     556
# 41  0.933197     556

# %%
import matplotlib.pyplot as plt
import numpy as np

# Get unique class names and models
class_names = report_df['Class'].unique()
model_names = report_df['Model'].unique()

# Set the number of classes and models
num_classes = len(class_names)
num_models = len(model_names)

# Set the width of each bar
bar_width = 0.8

# Set the positions of the bars on the x-axis
positions = np.arange(num_classes)

# Set the colors for the models
colors = ['red', 'blue', 'green', 'orange', 'purple']

# Create a dictionary to store the F1-Scores for each class
f1_scores_by_class = {class_name: [] for class_name in class_names}

# Iterate over each row in the dataframe
for _, row in report_df.iterrows():
    class_name = row['Class']
    f1_score = row['F1-Score']
    f1_scores_by_class[class_name].append(f1_score)

# Plot the F1-Scores for each class and model using a grouped bar plot
plt.figure(figsize=(10, 6))

# Iterate over each model
for i, model_name in enumerate(model_names):
    # Get the F1-Scores for the current model
    f1_scores = [f1_scores_by_class[class_name][i] for class_name in class_names]
    # Get the color for the current model
    color = colors[i % len(colors)]
    # Calculate the positions for the current model
    current_positions = positions + (i - num_models / 2 + 0.5) * bar_width / num_models
    # Plot the bars for the current model
    plt.bar(current_positions, f1_scores, width=bar_width / num_models, label=model_name, color=color)

plt.xlabel('Class')
plt.ylabel('F1-Score')
plt.title('F1-Score Comparison by Class and Model')
plt.xticks(positions, class_names)
plt.legend(title='Model')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming your DataFrame is named report_df
plt.figure(figsize=(12, 6))
sns.barplot(x='Model', y='Accuracy', data=report_df, ci=None)
plt.xticks(rotation=45)
plt.xlabel('Model')
plt.ylabel('Accuracy')
plt.title('Accuracy vs. Model')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\tejus\AppData\Local\Temp\ipykernel_1084\2650676806.py:6: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='Model', y='Accuracy', data=report_df, ci=None)
